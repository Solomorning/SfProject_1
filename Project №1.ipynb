# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ вакансий на hh.ru

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
hh_data = pd.read_csv('dst-3.0_16_1_hh_database.csv', sep = ';', encoding ='utf-8')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
hh_data.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %%
hh_data.shape[0]
# Out:
# 44744

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
hh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
hh_data.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
def edu_reform(x): # Функция преобразования
    x = x.lower()   
    x1 = x.split()   # Переводим к ловеркейсу и нарезаем по словам
    if(x1[1] in ('высшее', 'специальное')):  # А.Проверяем второе слово, если вариант неполное высшее или среднее специальное
        return x1[0] + ' ' + x1[1]
    elif(x1[0] in ('высшее', 'среднее')):    # Б.Проверяем первое слово, если вариант высшее или среднее общее и не-А.
        return x1[0]
    else:
        return x                               # В.Контроль.

hh_data['Образование'] = hh_data['Образование и ВУЗ'].apply(edu_reform) # Применяем функцию преобразования к каждой строке 
print(hh_data['Образование'].unique())   # Проверка, что нет лишних вариантов(вариант В)
print((hh_data['Образование'] == 'среднее').sum()) # Проверяем количество соискателей со средним общим образованием
hh_data = hh_data.drop('Образование и ВУЗ', axis=1)
# Out:
# ['неоконченное высшее' 'высшее' 'среднее специальное' 'среднее']
# 559

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
def sex_age_reform(x):  # Единая функция преобразования(возвращает tuple)
    x1 = x.split(sep=' , ') # создаёт список вида: [пол, возраст, дата рождения]
    x1[1] = x1[1].split() # возраст
    return x1[0][0], x1[1][0] # выводит пол и возраст кортежем

#hh_data['Пол, возраст'].apply(sex_age_reform).head()
serik = np.array([*hh_data['Пол, возраст'].apply(sex_age_reform)]) # Записываем получившийся кортеж как numpy массив.
hh_data['Пол'], hh_data['Возраст'] = serik[:, 0], np.int32(serik[:, 1]) # Получаем первую букву из пола(М или Ж) и интовый возраст.
print(hh_data.loc[:, ['Пол', 'Возраст']])       # Проверяем корректность полученных данных
print(hh_data['Пол'].value_counts()/44744*100)   
print(hh_data['Возраст'].mean())
hh_data = hh_data.drop('Пол, возраст', axis=1)
# Out:
#       Пол  Возраст
# 0       М       39
# 1       М       60
# 2       Ж       36
# 3       М       38
# 4       Ж       26
# ...    ..      ...
# 44739   М       30
# 44740   М       27
# 44741   Ж       48
# 44742   М       24
# 44743   М       38
#
# [44744 rows x 2 columns]
# М    80.929287
# Ж    19.070713
# Name: Пол, dtype: float64
# 32.19674146254246

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
def exp_reform(x):  # Функция преобразования 
    if x is np.nan:      
        return x
    if x == 'Не указано':  # Оставляем и добавляем пропуски согласно условию
        return np.nan
    x1 = x.split()        # Если не пропуск, нарезаем
    if x1[4].isdigit():     
        return (np.int16(x1[2])*12) + np.int16(x1[4]) # Если указаны и года и месяца
    elif x1[3][:5] == 'месяц':
        return np.int16(x1[2])   # Если опыт меньше года
    else:
        return np.int16(x1[2])*12  # Если указаны только года
    
print(hh_data['Опыт работы'].isna().sum())   
hh_data['Опыт работы (месяц)'] = hh_data['Опыт работы'].apply(exp_reform) #
print(hh_data['Опыт работы (месяц)'].isna().sum()) # Проверяем увеличились ли NaNы после прохождения функциия(да - на 2 позиции!)
hh_data = hh_data.drop('Опыт работы', axis=1)  
hh_data['Опыт работы (месяц)'].median()  # Проверяем медианный опыт
# Out:
# 168
# 170
# 100.0

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
'''См. выполнение задания в блоке ниже: проверяем все позиции где указаны только два параметра,
оказывается везде указан город, и везде указана готовность к переезду, поэтому ниже на проверке если сплит даёт 2 мы 
автоматически заполняем как x[0], True, False'''
def loc_check(x):   
    if len(x.split(sep=' , ')) == 2:
        return x

hh_data['Город, переезд, командировки'].apply(loc_check).unique()
# На всякий случай проверяем нет ли в случае, если указаны три пункта такого, что во втором пункте указано метро. Нету.
def loc_check2(x):
    x1 = x.split(sep=' , ')
    if (len(x1) == 3)&(x1[1][:2]=='м.'):
        return x

hh_data['Город, переезд, командировки'].apply(loc_check2).unique()
# Out:
# array([None], dtype=object)

# %%
def loc_reform(x):  # Функция преобразования
    million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону',
                  'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград' ] # Список городов миллиоников
    x1 = x.split(sep=' , ')
    # Этой веткой мы заполняем графу "Город"
    if x1[0] in million_cities:   
        x1[0] = 'город-миллионник'
    elif x1[0] not in ('Москва', 'Санкт-Петербург'):
        x1[0] = 'другие'
    # Случаи, когда указаны только 2 позиции рассмотрены выше. Меньше двух не указано нигде.
    if len(x1) == 2:
        return x1[0], True, False 
    # Этой веткой мы проверяем графу "Готовность к командировкам"
    if x1[-1][:8] == 'не готов':
        x1[-1] = False
    else:
        x1[-1] = True
    # Этой веткой мы проверяем графу "Готовность к переезду"
    if x1[-2][:8] == 'не готов':
        x1[-2] = False
    else:
        x1[-2] = True
    return x1[0], x1[-2], x1[-1]  # Возвращаем кортеж

loc_out = np.array([*hh_data['Город, переезд, командировки'].apply(loc_reform)]) # И сразу распаковываем его в массив
hh_data['Город'], hh_data['Готовность к переезду'], hh_data['Готовность к командировкам'] = loc_out[:, 0], loc_out[:, 1], loc_out[:, 2]
print(hh_data['Готовность к переезду'])  # Проверяем сработал ли второй if
print(hh_data['Город'].value_counts()/44744*100) # Высчитываем процент соискателей из каждой категории городов
#Выводим процент людей, готовых как к командировкам, так и к переезду.
print(((hh_data['Готовность к переезду']=='True')*(hh_data['Готовность к командировкам']=='True')).sum()/44744*100)
hh_data = hh_data.drop('Город, переезд, командировки', axis = 1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44739     True
# 44740     True
# 44741     True
# 44742    False
# 44743    False
# Name: Готовность к переезду, Length: 44744, dtype: object
# Москва              37.146880
# другие              35.432684
# город-миллионник    16.386555
# Санкт-Петербург     11.033882
# Name: Город, dtype: float64
# 31.928303236188093

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
# Функция преобразования
def employ_reform(x): 
    # Словарь возможных категория, создаётся для каждой строки датафрейма.
    employ = {'полная занятость': False, 'частичная занятость': False, 
              'проектная работа': False, 'стажировка': False, 'волонтерство': False}
    # Если категория есть в нарезанной строке, этот подпункт в словаре заменяется на true
    for i in x.split(', '):
        employ[i] = True
    return tuple(employ.values()) # Выводится как упорядоченный кортеж 

# Подаём все эти кортежи построчно в np.array и переименовываем названия столбцов по соответствующим категориям.
concat_df = pd.DataFrame(np.array([*hh_data['Занятость'].apply(employ_reform)])).rename(columns = {0: 'полная занятость',
                                                                                       1: 'частичная занятость', 
                                                                                       2: 'проектная работа', 
                                                                                       3: 'стажировка', 
                                                                                       4: 'волонтерство'})
# Конкатим к нашему датафрейму
hh_data = pd.concat([hh_data, concat_df], axis=1)
hh_data.drop('Занятость', axis=1)
display(hh_data)
# Out:
#                 ЗП                          Ищет работу на должность:  \
# 0       29000 руб.                            Системный администратор
# 1       40000 руб.                               Технический писатель
# 2       20000 руб.                                           Оператор
# 3      100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4      140000 руб.                  Региональный менеджер по продажам
# ...            ...                                                ...
# 44739   50000 руб.  Финансист, аналитик, экономист, бухгалтер, мен...
# 44740   39000 руб.             Системный администратор, IT-специалист
# 44741   40000 руб.                         Аналитик данных, Математик
# 44742   20000 руб.                                   Контент-менеджер
# 44743  120000 руб.                               Руководитель проекта
#
#                                                Занятость  \
# 0      частичная занятость, проектная работа, полная ...
# ...

# %%
# полный день, сменный график, гибкий график, удаленная работа, вахтовый метод(варианты)
# Аналогично, как и в блоке выше
def graphic_reform(x):
    graphic = {'полный день': False, 'сменный график': False, 'гибкий график': False, 'удаленная работа': False, 'вахтовый метод': False}
    for i in x.split(', '):
        graphic[i]=True
    return tuple(graphic.values())

concat_df = pd.DataFrame(np.array([*hh_data['График'].apply(graphic_reform)])).rename(columns = {0: 'полный день',
                                                                                       1: 'сменный график', 
                                                                                       2: 'гибкий график', 
                                                                                       3: 'удалённая работа', 
                                                                                       4: 'вахтовый метод'})
hh_data = pd.concat([hh_data, concat_df], axis = 1)
hh_data = hh_data.drop('График', axis = 1)
display(hh_data)
# Out:
#                 ЗП                          Ищет работу на должность:  \
# 0       29000 руб.                            Системный администратор
# 1       40000 руб.                               Технический писатель
# 2       20000 руб.                                           Оператор
# 3      100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4      140000 руб.                  Региональный менеджер по продажам
# ...            ...                                                ...
# 44739   50000 руб.  Финансист, аналитик, экономист, бухгалтер, мен...
# 44740   39000 руб.             Системный администратор, IT-специалист
# 44741   40000 руб.                         Аналитик данных, Математик
# 44742   20000 руб.                                   Контент-менеджер
# 44743  120000 руб.                               Руководитель проекта
#
#                                                Занятость  \
# 0      частичная занятость, проектная работа, полная ...
# ...

# %%
# Дополнительная проверка, что все нужные столбцы создались, и выполняем задания из lms.
print(hh_data.columns)
print((hh_data['проектная работа']&hh_data['волонтерство']).sum())
(hh_data['вахтовый метод']&hh_data['гибкий график']).sum()
# Out:
# Index(['ЗП', 'Ищет работу на должность:', 'Занятость',
#        'Последнее/нынешнее место работы', 'Последняя/нынешняя должность',
#        'Обновление резюме', 'Авто', 'Образование', 'Пол', 'Возраст',
#        'Опыт работы (месяц)', 'Город', 'Готовность к переезду',
#        'Готовность к командировкам', 'полная занятость', 'частичная занятость',
#        'проектная работа', 'стажировка', 'волонтерство', 'полный день',
#        'сменный график', 'гибкий график', 'удалённая работа',
#        'вахтовый метод'],
#       dtype='object')
# 436
# 2311

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
'''Я знаю, что можно сделать это через merge, но я решил попробовать написать функцию-конвертер, тем более, что там нужно
делать по сути всё то же самое. '''
def currency_reform(x, data):
    # По идее здесь подаётся строка из датафрейма, поэтому переопределим переменные для удобства.
    date, x = x[1], x[0].split()
    # функция, задающая маску по искомой валюте, и по дате(валюта задаётся в лямба функции ниже)
    mask = lambda cur: (data['currency']==cur)&(data['date']==date)
    # Отправляем в функцию уже преобразованные в ISO-формат названия валют и ожидаемую в этой валюте ЗП.
    convert = lambda a, b: data[mask(b)]['close'].iloc[0]*a/data[mask(b)]['proportion'].iloc[0]
    if x[1] in ['KZT', 'EUR', 'USD', 'KGS', 'AZN']:
        # Если валюты в формате ISO изначально, ничего не делаем
        return convert(np.int64(x[0]), x[1])
    elif x[1] != 'руб.':
        # Если валюты не в формате ISO и это не рубль - делаем перевод в ISO через словарь(словарь создаётся только в этой ветке).
        cur_dict = {'бел.руб.': 'BYN', 'сум': 'UZS', 'грн.': 'UAH'}
        return convert(np.int64(x[0]), cur_dict[x[1]])
    '''Обратите внимание, что мы не прогоняем convert для рубля, то есть для подавляющего большинства значений в таблице
    мы не обращаемся к датафрейму с курсами валют.'''
    return np.int64(x[0])

# %%
quotes = pd.read_csv('ExchangeRates.csv', sep=',')
quotes.drop('per', axis=1)
# Приводим к формату datetime64, но обнуляем время.
quotes['date'] = pd.to_datetime(quotes['date'], dayfirst=True).dt.normalize()
hh_data['Обновление резюме'] = pd.to_datetime(hh_data['Обновление резюме']).dt.date.astype('datetime64')
# Задаём из датафрейма построчно значения ЗП и дату обновления в функцию-конвертер, дополнительно подаём туда датафрейм с курсами.
hh_data['ЗП (руб)'] = hh_data.loc[:, ['ЗП', 'Обновление резюме']].apply(currency_reform, axis=1, data=quotes)
hh_data = hh_data.drop('ЗП', axis=1)
#Выводим медианную желаемую зарплату
hh_data['ЗП (руб)'].median()
# Out:
# 59000.0

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 8))
# Создаём seabornовский боксплот в вертикальной ориентации в левой ячейке
boxplot = sns.boxplot(
    data=hh_data,
    y='Возраст',
    width=0.75,
    color ='red',
    orient='v',
    ax=axes[0]
);
axes[0].set_title('Распределение возрастов соискателей', fontsize=16)
# В правой ячейке создаём гистограмму с предельно большим бином, чтоб оценить где расположена мода.
histagram = sns.histplot(
    x=hh_data["Возраст"], 
    label=["Гистограмма возрастов среди резюме соискателей"], 
    color="orange", 
    bins=100,
    kde=True,
    ax=axes[1]
)
axes[1].set_title("Гистограмма возрастов среди резюме соискателей")
axes[1].set_ylabel("Частота встречаемости соискателей соответсвующего возраста")
# Out:
# Text(0, 0.5, 'Частота встречаемости соискателей соответсвующего возраста')

# %% [markdown]
# По боксплоту видно, что доверительный интервал для возраста соискателей ограничен сверху примерно 50 годами, при этом больше половины людей находятся в возрастной группе от 20 до 40 лет. Несмотря на это, есть существенное количество выбросов, то есть соискателей в возрасте превышающем 50 лет. Это искревление можно видеть и на гистограмме.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Аналогично как и в блоке выше.
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 8))
boxplot = sns.boxplot(
    data=hh_data,
    y='Опыт работы (месяц)',
    width=0.75,
    color = 'red',
    orient='v',
    ax = axes[0]
);
axes[0].set_ylabel("Опыт работы в месяцах")
axes[0].set_title('Распределение опыта соискателей', fontsize=16)
histagram = sns.histplot(
    x=hh_data["Опыт работы (месяц)"], 
    label=["Гистограмма возрастов среди резюме соискателей"], 
    color="orange", 
    bins=100,
    ax = axes[1]
)
axes[1].set_title("Гистограмма опыта работы среди резюме соискателей")
axes[1].set_xlabel("Опыт работы в месяцах")
axes[1].set_ylabel("Частота встречаемости соискателей с соотвествующим опытом работы")
hh_data["Опыт работы (месяц)"].max()
# Out:
# 1188.0

# %% [markdown]
# Мода распределения не превышает 100 месяцев(вероятно находится на уровне приблизительно 70-80 месяцев примерно равное 6 лет), при этом доверительный интервал не превышает 300 месяцев (~25 лет), несмотря на наличие явного перекоса в большую сторону, т. е. существенного числа соискателей, чей опыт работы превышает 25, 30 и даже 40 лет, как и в случае с возрастом, в т. ч. совсем уж нереалистичные ~1200 месяцев=100 лет.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака ЗП? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Аналогично как и в двух блоках выше.
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 8))
boxplot = sns.boxplot(
    data=hh_data,
    y='ЗП (руб)',
    width=0.75,
    color = 'red',
    orient='v',
    ax = axes[0]
);
axes[0].set_title('Распределение желаемой ЗП', fontsize=16)
axes[0].set_ylabel("Желаемая заработная плата")
histagram = sns.histplot(
    x=hh_data["ЗП (руб)"],  
    color="orange", 
    bins=15,
    ax = axes[1]
)
axes[1].set_title("Гистограмма желаемой зарплаты в резюме у соискателей")
axes[1].set_ylabel("Частота встречаемости соискателей с соотвествующей заработной платой")
axes[1].set_xlabel("Желаемая заработная плата")
# Out:
# Text(0.5, 0, 'Желаемая заработная плата')

# %% [markdown]
# Из-за выбросов информация существенно искажена, однако можно ссказать, что подавляющее большинство указанных желаемых заработных плат не превышают 1 миллион в месяц. При этом есть 5 выбросов, среди которых выброс в виде желаемой ЗП примерно равной 25 миллионам рублей.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
fig = plt.figure(figsize=(12, 8))
# Делаем столбчатую диаграмму, чтобы посмотреть насколько отличаются значения для разных уровней образования
barplot = sns.barplot(
    # Через groupby группируем данные по категории "Образование", чтобы потом посчитать для каждой медиану.
    data=hh_data.loc[:, ['Образование', 'ЗП (руб)']].groupby(by = 'Образование',  as_index=False).median(),
    x = 'Образование',
    y = 'ЗП (руб)',
)
barplot.set_title('Медианная зарплата в зависимости от уровня образования');
barplot.set_xlabel('Уровень образования');
barplot.set_ylabel('Медианная заработная плата в пересчёте в рублях');

# %% [markdown]
# Нетрудно заметить, что наибольшая медианная ЗП соответствует высшему образованию. Помимо непосредственной полезности образования для компетенций трудящегося здесь, скорее всего, играет роль также и косвенная корреляция, говорящая о том, что человек, который может позволить себе окончение ВУЗа, имеет больше средств и времени на освоении новых компетенций и, вероятно, имеет более высокие способности(в среднем), поэтому в будущем сможет претендовать на большую зарплату. При этом медианная ЗП для среднего и среднего специального находится примерно на одном и том же уровне, и люди из такой категории имеют наименьшую медианную зарплату.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
fig = plt.figure(figsize=(12, 8))
# Создаём боксплоты для каждой категории городов и сравниваем
boxplot = sns.boxplot(
    # Берём данные без выбросов сверху
    data=hh_data.loc[(hh_data['ЗП (руб)']<1000000), ['Город', 'ЗП (руб)']],
    x = 'Город',
    y = 'ЗП (руб)',
    width=0.75,
    color = 'violet',
    orient = 'v'
);
boxplot.set_title('Зависимость разброса ожидаемой ЗП от местоположения соискателя')
boxplot.set_xlabel('Место проживания')
boxplot.set_ylabel('Желаемая заработная плата')
# Out:
# Text(0, 0.5, 'Желаемая заработная плата')

# %% [markdown]
# Несмотря на большое количество выбросов, эти боксплоты в целом демонстрируют обшую тенденцию, в том, что наибольшая зарплата в Москве, затем в Санкт-Петербурге, а в городах-миллионниках и прочих городах нельзя обнаружить существенных различий. При этом Москва существенно превосходит остальные города не только по медианному уровню заработной платы, но и по разбросу, имея значительно больший разброс, чем в городах миллионниках и прочих городах. Несомненно, локация играет важную роль при определеннии заработной платы трудящегося.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
pivot_df = hh_data.loc[:, ['Готовность к командировкам', 'Готовность к переезду','ЗП (руб)']].groupby(by = ['Готовность к командировкам',
                                                                                                            'Готовность к переезду'], 
                                                                                                          as_index=False).median()

display(pivot_df)
fig = px.bar(pivot_df, x="Готовность к переезду", y="ЗП (руб)", color="Готовность к командировкам",
             title="Медианная желаемая заработная плата в зависимости от готовности к релокации")

fig.show()
# Out:
#   Готовность к командировкам Готовность к переезду  ЗП (руб)
# 0                      False                 False   40000.0
# 1                      False                  True   50000.0
# 2                       True                 False   60000.0
# 3                       True                  True   68000.0
# ...

# %% [markdown]
# Нетрудно заметить, что готовность к командировкам более резко влияет на ожидаемую заработную плату, чем готовность к переезду. В случае, если человек готов к переезду, он даёт прирост к медианной заработной платы в 17 т. р.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
fig = plt.figure(figsize=(12, 8))
pivot_df = hh_data.loc[:, ['Образование', 'Возраст','ЗП (руб)']].groupby(by = ['Образование','Возраст'], as_index=False).median().pivot_table(
    values='ЗП (руб)',
    columns='Возраст',
    index='Образование',
)
pivot_df.columns = pivot_df.columns.astype('string')
hm = sns.heatmap(data=pivot_df)
hm.set_title('Тепловая карта зависимости ЗП от возраста и образования', fontsize = 16);

# %% [markdown]
# Тепловая карта слева направа показывает рост заработной платы при увеличении возраста по контрасту. Диапозон этого контраста демонстрирует то, насколько фактор образования влияет на рост заработной платы по мере взросления. Так, нетрудно заметить, что выпускинки средних специальных учебных заведений достигают пика заработных плат примерно к 25 годам, и после этого существенно они не возрастают(не считая проотиворечивые данные для 60+ лет). Данные для среднего неспециального образования в целом очень противоречивы, здесь трудно сказать что-то положительно(потому что от года к году наблюдаются труднообъяснимые чем-то помимо помех в данных скачки в зарплатах). Люди с неоконченным высшим достигают почти столь же высоких заработных плат, как и люди с высшим образованием, но при этом существенно позже(на 5-10 лет), чем люди с высшим образованием. Это можно объяснить необходимость восполнить нехватку знания, опыта, сноровки, а также тем, что люди, бросившие учёбу в ВУЗе, скорее всего, с большей вероятностью будут длительное время находится в состоянии творческого поиска. Наконец, наиболее ранний и наиболее интенсивный рост заработных плат с возрастом характерен именно для выпускников ВУЗов.
# Характерно, что до 24 лет существенного влияния образование на уровень заработных плат, по видимому, не оказывает.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
fig = plt.figure(figsize=(12, 8))
axes = fig.add_axes([0, 0, 1, 1])
axes.scatter(
    x=hh_data['Возраст'], 
    y=hh_data['Опыт работы (месяц)']/12, 
    s=15,
    marker='o',
    c = 'lime'
);
sns.lineplot(data = hh_data, x="Возраст", y="Возраст")
axes.set_ylabel('Опыт работы(в годах)')
axes.set_title('Диаграмма рассеяния возраста и опыта работы у соискателей')
# Out:
# Text(0.5, 1.0, 'Диаграмма рассеяния возраста и опыта работы у соискателей')

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# ваш код здесь

# %% [markdown]
# ваши выводы здесь

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# Проверяем объём данных до и после удаления дубликатов
display(hh_data.shape[0])
hh_data = hh_data.drop_duplicates()
hh_data.shape[0]
# Out:
# 44744
# 44585

# %%
# Посмотрим, сколько дубликатов удалилось.
44744-44585
# Out:
# 159

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# Сколько NaNов.
hh_data.isna().sum(axis = 0)
# Out:
# Ищет работу на должность:            0
# Занятость                            0
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# Обновление резюме                    0
# Авто                                 0
# Образование                          0
# Пол                                  0
# Возраст                              0
# Опыт работы (месяц)                168
# Город                                0
# Готовность к переезду                0
# Готовность к командировкам           0
# полная занятость                     0
# частичная занятость                  0
# проектная работа                     0
# стажировка                           0
# волонтерство                         0
# полный день                          0
# сменный график                       0
# гибкий график                        0
# удалённая работа                     0
# вахтовый метод                       0
# ЗП (руб)                             0
# dtype: int64

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# Удаляем пропуски в данных по месту работы и должности
hh_data = hh_data[(hh_data['Последнее/нынешнее место работы'].notna())&(hh_data['Последняя/нынешняя должность'].notna())]
# Пропуски в опыте работы заполняем медианой
exp_med = hh_data['Опыт работы (месяц)'].median()
hh_data['Опыт работы (месяц)'].fillna(exp_med, inplace = True)
# Проверяем, что пропусков больше не осталось, и выводим получившееся среднее от опыта работы соискателей.
hh_data.isna().sum(axis = 0)
hh_data['Опыт работы (месяц)'].mean()
# Out:
# 114.35540452638898

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# Делаем маску для выброса
drop_mask = (hh_data['ЗП (руб)']>1000000)|(hh_data['ЗП (руб)']<1000)
# Копируем выбросы, чтобы потом на них посмотреть
outliers = hh_data[drop_mask].copy()
# Удаляем выбросы из данных
hh_data = hh_data[~drop_mask]
# Смотрим на выбросы
display(outliers)
# Out:
#                                Ищет работу на должность:  \
# 253              Руководитель аналитики/crm/data science
# 514                        Oracle DBA, системный инженер
# 552                                          3D художник
# 1087         Директор по продукту {Internet, Blockchain}
# 2248   Электромонтер КИПиА, электромеханик, IT, сеть ...
# ...                                                  ...
# 42329                               Инженер- программист
# 42841                    Ведущий системный администратор
# 43134                                   Chief AI Officer
# 43385  Директор по управлению проектами / Директор по...
# 44107                                    Web-разработчик
#
#                                                Занятость  \
# 253                                     полная занятость
# 514    проектная работа, частичная занятость, полная ...
# 552    стажировка, волонтерство, частичная занятость,...
# ...

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# Аналогично предыдущему блоку
drop_mask = hh_data['Опыт работы (месяц)']/12>hh_data['Возраст']
outliers = hh_data[drop_mask].copy()
hh_data = hh_data[~drop_mask]
display(outliers)
# Out:
#              Ищет работу на должность:  \
# 4535            Технический специалист
# 19351  Специалист (Junior-программист)
# 19872                         Аналитик
# 26477             Менеджер IT-проектов
# 29098      Ведущий инженер-программист
# 40015  Системный администратор Windows
# 43451   Руководитель отдела разработки
#
#                                                Занятость  \
# 4535   частичная занятость, проектная работа, полная ...
# 19351                                   полная занятость
# 19872                                   полная занятость
# 26477  стажировка, волонтерство, частичная занятость,...
# 29098                                   полная занятость
# 40015              частичная занятость, полная занятость
# 43451                                   полная занятость
#
#                          Последнее/нынешнее место работы  \
# 4535                                                   а
# 19351                                  Русский свет, ООО
# ...

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
# Отрисовываем log-шкалу для частоты встречаемости соискателей разных возрастов
fig = plt.figure(figsize=(10, 4))
axes = fig.add_axes([0, 0, 1, 1])
# Переводим возраст в log-шкалу
log_age = np.log(hh_data['Возраст'] + 1)
# Создаём гистограмму
axes.hist(
    x=log_age, label=["Распределение возрастов соискателей"], color="violet", bins=25
)
# Считаем среднее и обозначаем его на графике
mean_val = log_age.mean()
axes.axvline(mean_val, color='k', lw=2)
# Считаем три сигмы и обозначаем на графике правило трёх сигм
sigma = 3*log_age.std()
axes.axvline(mean_val+sigma, color='k', lw=2)
axes.axvline(mean_val-sigma, color='k', lw=2)
# Подписываем
axes.set_title('Распределение возрастов соискателей на log-шкале')
axes.set_xlabel('Натуральный логарифм от возраста соискателей')
axes.set_ylabel('Частота встречаемости соискателей соответсвующего возраста')
# Out:
# Text(0, 0.5, 'Частота встречаемости соискателей соответсвующего возраста')

# %%
# Делаем маску в соответсвии с условием выделения выброса и смотрим на них.
hh_data[(np.log(hh_data["Возраст"]+1)>(mean_val+4/3*sigma))|(np.log(hh_data["Возраст"]+1)<(mean_val-sigma))]
# Out:
#             Ищет работу на должность:  \
# 31137  Менеджер по работе с клиентами
# 32950                 Тестировщик игр
# 33654            Frontend-разработчик
#
#                                                Занятость  \
# 31137                                частичная занятость
# 32950                                   полная занятость
# 33654  стажировка, частичная занятость, проектная раб...
#
#       Последнее/нынешнее место работы    Последняя/нынешняя должность  \
# 31137           ООО "ФёрстКэшКомпани"  Менеджер по работе с клиентами
# 32950                        OOO ЖМЫХ                  Тестировщик ПО
# 33654                       Freelance            Frontend-разработчик
#
#       Обновление резюме        Авто          Образование Пол  Возраст  \
# 31137        2019-06-04  Не указано              среднее   М       15
# 32950        2019-09-04  Не указано  среднее специальное   М       15
# 33654        2019-04-19  Не указано  среднее специальное   М      100
#
# ...

# %% [markdown]
# ваш коммментарий здесь
